# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# %%
df=pd.read_csv("drive/My Drive/Notebook/healthcare_data.csv")

# %%
df.head()
# Out:
#    Patient_ID    Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0        1001      John Smith   45    Male         A+   Hypertension
# 1        1002        Jane Doe   62  Female         B-       Diabetes
# 2        1003  Robert Johnson   35    Male         O+         Cancer
# 3        1004    Susan Wilson   78  Female         A-  Heart Disease
# 4        1005   Michael Brown   55    Male        AB+         Asthma
#
#    Treatment_Cost
# 0         1200.50
# 1          800.75
# 2         5500.00
# 3         2700.25
# 4          400.00

# %%
patient_ages = [49,38,54,58,41,47,35,60,53,49,56,44,65,30,70,35,52,57,43,62,41,46,51,55,42,59,64,40,39,34,47]

# %%
plt.figure(figsize=(10, 6))
plt.hist(patient_ages, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Patient Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df.groupby(['Age'])[['Gender']].sum()
# Out:
#                Gender
# Age
# 29               Male
# 30         FemaleMale
# 33               Male
# 34               Male
# 35     MaleFemaleMale
# 38               Male
# 39             Female
# 40         FemaleMale
# 41       FemaleFemale
# 42       FemaleFemale
# 43             Female
# 44           MaleMale
# 45               Male
# 46               Male
# 47         MaleFemale
# 48               Male
# 49         FemaleMale
# 51       FemaleFemale
# 52             Female
# 53             Female
# 54             Female
# 55       MaleMaleMale
# 56             Female
# 57               Male
# 58               Male
# 59               Male
# 60               Male
# 62   FemaleFemaleMale
# 64             Female
# 65       FemaleFemale
# 67               Male
# 70       FemaleFemale
# 72               Male
# 78             Female

# %%
df.groupby(['Diagnosis'])[['Gender']].sum()
# Out:
#                                                           Gender
# Diagnosis
# Asthma         MaleFemaleFemaleFemaleMaleFemaleMaleFemaleMale...
# Cancer         MaleFemaleFemaleFemaleMaleFemaleMaleFemaleMale...
# Diabetes       FemaleMaleMaleFemaleFemaleMaleFemaleMaleFemale...
# Heart Disease   FemaleMaleMaleMaleFemaleMaleFemaleMaleFemaleMale
# Hypertension    MaleFemaleMaleMaleMaleFemaleMaleFemaleMaleFemale

# %%
df.groupby(['Blood_Type'])[['Treatment_Cost']].sum()
# Out:
#             Treatment_Cost
# Blood_Type
# A+                25161.50
# A-                 7351.50
# AB+                8930.75
# AB-                5771.50
# B+                 1720.50
# B-                 1721.50
# O+                17220.75
# O-                 9676.25

# %% [markdown]
# Blood Type A+ has the highest average cost

# %%
df.groupby(['Gender'])[['Diagnosis']].sum()
# Out:
#                                                 Diagnosis
# Gender
# Female  DiabetesHeart DiseaseHypertensionCancerAsthmaC...
# Male    HypertensionCancerAsthmaDiabetesHeart DiseaseH...
